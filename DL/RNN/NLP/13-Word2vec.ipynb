# %%
##word2vec --- words into dense vectors representations where semantically 
# smiliar words are close to each other  

## 2013 published by Google -- news trained  

#range = -1 to 1

# %%
##similarity  --- how similar are two words to each other

##example -- netflix -- iron man - superheroes

# %%
            boy     girl    king    queen   apple 
Gender      -1       1     -0.92    +0.92    0.005
royal       0.01   0.02     0.99   -0.99    0.01
age
food

# %%
pip install gensim
# Out:
# ...
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---- ----------------------------------- 2.9/24.0 MB 18.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 6.6/24.0 MB 20.1 MB/s eta 0:00:01
#    -------------- ------------------------- 8.7/24.0 MB 15.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 10.7/24.0 MB 13.7 MB/s eta 0:00:01
#    -------------------------------------- - 23.3/24.0 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------------- 24.0/24.0 MB 22.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ----------- ---------------------------- 12.8/46.2 MB 62.0 MB/s eta 0:00:01
#    --------------------- ------------------ 25.2/46.2 MB 59.2 MB/s eta 0:00:01
#    -------------------------------- ------- 37.0/46.2 MB 58.7 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.2 MB 58.7 MB/s eta 0:00:01
# ...

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api
model = api.load('word2vec-google-news-300')

# %%
model.most_similar('king')
# Out:
# [('kings', 0.7138045430183411),
#  ('queen', 0.6510956883430481),
#  ('monarch', 0.6413194537162781),
#  ('crown_prince', 0.6204220056533813),
#  ('prince', 0.6159993410110474),
#  ('sultan', 0.5864824056625366),
#  ('ruler', 0.5797567367553711),
#  ('princes', 0.5646552443504333),
#  ('Prince_Paras', 0.5432944297790527),
#  ('throne', 0.5422105193138123)]
